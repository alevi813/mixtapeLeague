# %%
# import numpy, pandas, spotipy
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt 
import seaborn as sns

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
client_credentials_manager = SpotifyClientCredentials(client_id= '6426e18767ac42d78a9c08f41cacba65',
                                                     client_secret= '4a2cdab50e1c4ecd9fc62cae20664e29')
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# read in data from excel sheet, do a bit of cleanup
allMixes = pd.ExcelFile('/Users/aaronlevi/Documents/fantasyMixtape.xlsx')
nMixes   = len(allMixes.sheet_names)

# allSongs = pd.read_excel('/Users/aaronlevi/Documents/fantasyMixtape.xlsx', sheet_name=0);
# allSongs.drop([0], axis=0, inplace=True)
allSongs = []

for kMix in range(0,nMixes):
    thisMix = pd.read_excel('/Users/aaronlevi/Documents/fantasyMixtape.xlsx', sheet_name=kMix)
    thisMix.drop([0], axis=0, inplace=True)
    
    allSongs.append(thisMix)

# %%
allSongs
# Out:
#    Unnamed: 0                                         Unnamed: 1  \
# 1     NATALIE                                Africando - “Aïcha”
# 2        MIKE              Tom Misch & Yussef Dayes - “Last 100”
# 3        JAKE                       David Byrne - “Life Is Long”
# 4        NICK                 Joe Bataan - “Ordinary Guy Part 2”
# 5       AARON                      The Aggrolites - “Funky Fire”
# 6     GILLIAN                                 Remi Wolf - “Woo!”
# 7      ALEX M  Joey Ryan & The Inks - “Fare Thee Well Poor Gh...
# 8         SAM        Shakira (ft. Alejandro Sanz) - “La Tortura”
# 9       EITAN    Spirit Family Reunion - “It Does Not Bother Me”
# 10      STEVE                Apollo Sunshine - “Fear Of Heights”
# 11        TIM                The Front Bottoms - “Vacation Town”
# 12      EMILY                     Hippie Sabotage - “Rich Girls”
# 13     RACHEL                Summer Salt - “Time Away From Home”
# 14        TOM                         Joe Strummer - “Coma Girl”
# 15       JOSH                               Larytta - "Promises"
# 16    REBECCA                              Dijon - “Rock N Roll”
# 17       EVAN   Queens Of The Stone Age - "How To Handle A Rope”
# 18       ADAM                             Purr - “Take You Back”
# 19        BEN                       The Cool Kids - “Summer Jam”
# 20       ANDY                                 Gold Panda - “You”
# 21      DEANA                       CHAI - “Ready Cheeky Pretty”
# 22     ALEX T                            Bassnectar - “Loco Ono”
# 1        MIKE                       Dance Gavin Dance - “Say Hi”
# 2        NICK                      Nirvana - “Tourette’s [live]”
# 3     REBECCA               Hayley Heynderickx - “Oom Sha La La”
# 4      RACHEL                                Brutus - “Cemetery”
# 5         TIM                     Cloud Nothings - “Wasted Days”
# 6      ALEX T                Nine Inch Nails - “She’s Gone Away”
# 7       EITAN                      Prince - “The Beautiful Ones”
# 8         SAM                      Fucked Up - “Queen Of Hearts”
# ..        ...                                                ...
# 15      EMILY                            Eastern Youth - “沸点36º”
# 16        TOM                        The Finger - “Coma For $$$”
# 17     ALEX T   The Dear Hunter - “The Bitter Suite I and II: …"
# 18    GILLIAN  Joomanji (ft. Copasetic & Lindsay Owen) - “Whe...
# 19      STEVE                             Desaparecidos - “$$$$”
# 20       EVAN                  Blank Banshee - “Anxiety Online!”
# 21        SAM  Battlefield Band - “The Devil’s Courtship / An...
# 22       JAKE                 Devendra Banhart - “Is This Nice?”
# 1           1                                                SAM
# 2           2                                               EVAN
# 3           3                                              AARON
# 4           4                                             RACHEL
# 5           5                                               MIKE
# 6           6                                              EITAN
# 7           7                                                TOM
# 8           8                                               JAKE
# 9           9                                                BEN
# 10         10                                              EMILY
# 11         11                                               ADAM
# 12          1                                              DEANA
# 13          2                                            NATALIE
# 14          3                                               JOSH
# 15          4                                                TIM
# 16          5                                             ALEX M
# 17          6                                               ANDY
# 18          7                                               NICK
# 19          8                                            GILLIAN
# 20          9                                             ALEX T
# 21         10                                              STEVE
# 22         11                                            REBECCA
#
#                                           Unnamed: 2 Unnamed: 3 Unnamed: 4
# 1                                                 12          5        NaN
# 2                                                 12          6        NaN
# 3                                                 11          9        NaN
# 4                                                  9          4        NaN
# 5                                                  9          5        NaN
# 6                                                 30         14        NaN
# 7                                                 10          7        NaN
# 8                                                  0          0        NaN
# 9                                                 15          6        NaN
# 10                                                22          9        NaN
# 11                                                 2          1        NaN
# 12                                                11          6        NaN
# 13                                                 9          7        NaN
# 14                                                12          6        NaN
# 15                                                22         10        NaN
# 16                                                13          6        NaN
# 17                                                13          6        NaN
# 18                                                12          6        NaN
# 19                                                19          8        NaN
# 20                                                10          5        NaN
# 21                                                11          6        NaN
# 22                                                 0          0        NaN
# 1                                                  3          2        NaN
# 2                                                  2          1        NaN
# 3                                                 17          7        NaN
# 4                                                 24         14        NaN
# 5                                                 21          9        NaN
# 6                                                  7          3        NaN
# 7                                                 12          6        NaN
# 8                                                 16          8        NaN
# ..                                               ...        ...        ...
# 15                                                10          6        NaN
# 16                                                 3          2        NaN
# 17                                                 0          0        NaN
# 18                                                14          7        NaN
# 19                                                10          4        NaN
# 20                                                 5          3        NaN
# 21                                                 8          4        NaN
# 22                                                15          8        NaN
# 1    Western Mass Sacred Harp Convention - “Detroit”          6          3
# 2                             Death Grips - “Hacker"          7          5
# 3                            Juana Molina - “Cosoco”         16          7
# 4                     Maryam Saleh - “Nouh Al Hamam”         18          9
# 5                        #1 Dads - “Freedom Fighter”          2          1
# 6            Theo Katzman - “You Could Be President”          8          4
# 7                  Kim Carnes - “Crazy In The Night”         13          9
# 8                              Dude York - “Burnin’”          6          3
# 9                         Adrianne Lenker - “Symbol”         11          6
# 10                      Snarls - “Walk In The Woods”         26         11
# 11                          Beach Bunny - “Promises”         19          8
# 12         Sudan Archives - “Pelicans In The Summer”         10          5
# 13               Jovanotti - “La Notte Dei Desideri”          9          4
# 14       The Sundays - "Here's Where The Story Ends"         14          6
# 15                  And The Kids - "No Way Sit Back"         20         10
# 16         Victoria Bigelow - “Something / Anything”         13          8
# 17                         Jessie Ware - “Spotlight”         13          6
# 18                           Diggs Duke - “The Cure”         11          5
# 19                                  Softee - "Oh No"         19         10
# 20  Jolie Holland, Thor & Friends - “Louisiana 1927”          1          1
# 21                    Frances Quinlan - “Went To LA”         13          6
# 22                            Beck - "Saw Lightning"          9          5
#
# [264 rows x 5 columns]
